# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "Josee Uwamariya"
# !git config --global user.email "joseeuwa@gmail.com"

# !git config --list
# Out:
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# user.name=Josee Uwamariya
# user.email=joseeuwa@gmail.com

# %%
# !git clone https://github.com/joseeuwa/colab-git-assignment2.git
# Out:
# Cloning into 'colab-git-assignment2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd colab-git-assignment2
# !ls
# Out:
# /content/colab-git-assignment2
# README.md

# %% [markdown]
# # Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %%
# !pwd
# !ls
# Out:
# /content/colab-git-assignment2
# README.md
